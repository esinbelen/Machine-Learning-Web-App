# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
import skimage
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
skimage.__version__
# Out:
# '0.19.2'

# %%
# load the data
data = pickle.load(open('data_animals_head_20.pickle','rb'))

# %%
data['description']
# Out:
# 'There are 20 classes and 2057 images are there. All the images are 80 x 80 (rgb)'

# %%
# split the data into independent and dependent
X = data['data'] # independent
y = data['target'] # dependent

# %%
print(X)
# Out:
# [[[[196 214 188]
#    [196 214 188]
#    [196 214 188]
#    ...
#    [ 81  76  80]
#    [ 81  76  80]
#    [ 69  64  68]]
#
#   [[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 82  77  81]
#    [ 83  78  82]
#    [ 77  72  76]]
#
#   [[193 213 185]
#    [194 214 186]
#    [194 214 186]
#    ...
#    [ 82  77  81]
#    [ 81  76  80]
#    [ 78  73  77]]
#
#   ...
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 70  65  69]
#    [ 65  60  64]
#    [ 62  57  63]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 66  61  65]
#    [ 62  57  61]
#    [ 64  59  65]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 56  51  55]
#    [ 79  74  78]
#    [ 70  63  70]]]
#
#
#  [[[  4   2   3]
#    [  7   5   6]
#    [  6   5   3]
#    ...
#    [ 42  31  25]
#    [ 46  35  29]
#    [ 45  32  26]]
#
#   [[  7   5   6]
#    [  5   4   2]
#    [  2   1   0]
#    ...
#    [ 22  11   5]
#    [ 43  32  26]
#    [ 47  36  30]]
#
#   [[  6   5   3]
#    [  3   2   0]
#    [  2   1   0]
#    ...
#    [ 33  24  17]
#    [ 48  39  32]
#    [ 54  45  38]]
#
#   ...
#
#   [[ 24  29   6]
#    [ 24  30   4]
#    [ 25  31   5]
#    ...
#    [116 116  80]
#    [115 117  80]
#    [127 129  92]]
#
#   [[ 22  27   4]
#    [ 23  28   5]
#    [ 24  29   6]
#    ...
#    [112 112  76]
#    [115 117  80]
#    [128 130  93]]
#
#   [[ 22  27   5]
#    [ 22  27   4]
#    [ 22  27   4]
#    ...
#    [106 106  70]
#    [112 114  77]
#    [126 128  91]]]
#
#
#  [[[104 109 102]
#    [104 111 103]
#    [108 115 107]
#    ...
#    [130 126 127]
#    [122 117 121]
#    [123 118 122]]
#
#   [[113 118 111]
#    [ 97 104  96]
#    [103 110 102]
#    ...
#    [111 107 108]
#    [129 124 128]
#    [150 145 149]]
#
#   [[126 133 125]
#    [112 119 111]
#    [110 117 109]
#    ...
#    [139 135 136]
#    [162 157 161]
#    [163 158 162]]
#
#   ...
#
#   [[214 214 202]
#    [206 206 194]
#    [202 200 187]
#    ...
#    [164 162 150]
#    [173 173 163]
#    [187 187 179]]
#
#   [[219 219 207]
#    [210 210 198]
#    [205 203 190]
#    ...
#    [170 168 156]
#    [174 174 164]
#    [188 188 180]]
#
#   [[214 214 202]
#    [201 201 189]
#    [198 196 183]
#    ...
#    [172 170 158]
#    [179 179 169]
#    [184 184 176]]]
#
#
#  ...
#
#
#  [[[147 154 113]
#    [145 152 111]
#    [146 153 112]
#    ...
#    [102 109  58]
#    [118 121  74]
#    [128 131  86]]
#
#   [[148 155 114]
#    [146 153 112]
#    [145 152 111]
#    ...
#    [120 128  71]
#    [138 142  91]
#    [151 155 105]]
#
#   [[147 154 112]
#    [146 153 111]
#    [144 151 109]
#    ...
#    [136 142  80]
#    [143 151  91]
#    [150 158  99]]
#
#   ...
#
#   [[137 142  88]
#    [146 150  99]
#    [145 148 101]
#    ...
#    [143 138 100]
#    [148 143 103]
#    [158 150 111]]
#
#   [[133 138  82]
#    [128 133  79]
#    [129 133  83]
#    ...
#    [158 153 115]
#    [157 152 112]
#    [154 149 109]]
#
#   [[130 135  79]
#    [128 133  79]
#    [135 139  88]
#    ...
#    [160 155 115]
#    [157 152 112]
#    [150 145 105]]]
#
#
#  [[[246 250 249]
#    [247 251 250]
#    [252 254 253]
#    ...
#    [136 118 114]
#    [143 124 118]
#    [145 126 120]]
#
#   [[244 248 247]
#    [252 255 255]
#    [243 245 244]
#    ...
#    [139 124 117]
#    [135 120 113]
#    [156 141 134]]
#
#   [[238 242 241]
#    [248 252 251]
#    [246 248 247]
#    ...
#    [128 118 109]
#    [128 118 109]
#    [141 131 122]]
#
#   ...
#
#   [[236 233 224]
#    [230 226 217]
#    [228 224 215]
#    ...
#    [159 142 126]
#    [152 135 119]
#    [150 133 117]]
#
#   [[234 231 222]
#    [233 230 221]
#    [229 225 216]
#    ...
#    [185 169 154]
#    [165 149 134]
#    [169 153 138]]
#
#   [[242 239 232]
#    [236 233 224]
#    [229 225 216]
#    ...
#    [193 177 162]
#    [185 169 154]
#    [175 159 144]]]
#
#
#  [[[ 85  78  32]
#    [ 79  72  26]
#    [ 79  72  26]
#    ...
#    [ 80  73  27]
#    [ 76  69  23]
#    [ 74  67  21]]
#
#   [[ 82  78  31]
#    [ 79  72  26]
#    [ 78  71  25]
#    ...
#    [ 78  71  25]
#    [ 75  68  24]
#    [ 71  64  20]]
#
#   [[ 81  77  30]
#    [ 80  73  27]
#    [ 77  70  24]
#    ...
#    [ 78  71  27]
#    [ 76  69  25]
#    [ 71  64  20]]
#
#   ...
#
#   [[ 85  55  17]
#    [ 92  60  22]
#    [ 90  58  20]
#    ...
#    [103 101  53]
#    [ 99  97  49]
#    [ 96  94  46]]
#
#   [[ 87  57  19]
#    [ 82  50  11]
#    [ 88  56  17]
#    ...
#    [104 100  53]
#    [101  97  50]
#    [ 98  94  47]]
#
#   [[ 82  53  13]
#    [ 83  51  12]
#    [ 92  60  21]
#    ...
#    [101  94  48]
#    [100  93  47]
#    [ 98  91  45]]]]

# %%
print(y)
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', ' ...

# %%
# split the data into train and test
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
x_train.shape,x_test.shape,len(y_train),len(y_test)
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3), 1645, 412)

# %% [markdown]
# ---
# ####  Feature Extraction
# - Hog
# [URL](https://www.analyticsvidhya.com/blog/2019/09/feature-engineering-images-introduction-hog-feature-descriptor/#:~:text=HOG%2C%20or%20Histogram%20of%20Oriented,vision%20tasks%20for%20object%20detection.)

# %%
img = skimage.io.imread('lion.jpg')
plt.figure(figsize=(6,10))
plt.imshow(img)

# %%
# hog transoform
gray = skimage.color.rgb2gray(img)
feature_vector, hog_img = skimage.feature.hog(gray, orientations=9,
                    pixels_per_cell=(14,14),
                    cells_per_block=(2,2),
                    visualize=True)

# %%
len(feature_vector)
# Out:
# 102060

# %%
gray.shape
# Out:
# (907, 645)

# %%
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing
# - Grayscale
# - Hog (histogram oriented gradient) tranformer

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from skimage.color import rgb2gray

# %%
class rgb2gray_transform(BaseEstimator,TransformerMixin):
    import skimage.color
    def __init__(self):
        pass
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
x_train.shape
# Out:
# (1645, 80, 80, 3)

# %%
rgb2grayobj = rgb2gray_transform()
x_train_gray = rgb2grayobj.fit_transform(x_train)

# %%
x_train_gray.shape
# Out:
# (1645, 80, 80)

# %%
plt.subplot(1,2,1)
plt.imshow(x_train[12])
plt.subplot(1,2,2)
plt.imshow(x_train_gray[12],cmap='gray')

# %%
class hogtransformer(BaseEstimator,TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8, 8),cells_per_block=(3, 3),):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features= skimage.feature.hog(img,orientations=self.orientations,
                                pixels_per_cell=self.pixels_per_cell,
                                cells_per_block=self.cells_per_block)
            
            return hog_features
        
        hfeatures = np.array([local_hog(x) for x in X])
        return hfeatures

# %%
hogt = hogtransformer()

# %%
x_train_hog = hogt.fit_transform(x_train_gray)

# %%
x_train_hog.shape
# Out:
# (1645, 5184)

# %% [markdown]
# ### Training Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',
                          early_stopping=True,eta0=0.1,)

# %%
x_train.shape,x_test.shape
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hogify = hogtransformer()
scalify = StandardScaler()

# %%
# pipeline
# step-1: convert into grayscale
x_train_gray = grayify.fit_transform(x_train)
# step-2: extract the features
x_train_hog = hogify.fit_transform(x_train_gray)
# step-3: Normalization
x_train_scale = scalify.fit_transform(x_train_hog)
# step-4: machine learning
model_sgd.fit(x_train_scale,y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
x_test_gray = grayify.fit_transform(x_test)
# step-2: extract the features
x_test_hog = hogify.fit_transform(x_test_gray)
# step-3: Normalization
x_test_scale = scalify.transform(x_test_hog)

y_pred_test = model_sgd.predict(x_test_scale)

# %%
y_pred_test
# Out:
# array(['lion', 'monkey', 'pigeon', 'cow', 'cat', 'human', 'cow', 'sheep',
#        'bear', 'tiger', 'cow', 'mouse', 'chicken', 'cow', 'mouse',
#        'tiger', 'panda', 'mouse', 'cat', 'tiger', 'human', 'wolf',
#        'sheep', 'elephant', 'wolf', 'wolf', 'sheep', 'tiger', 'rabbit',
#        'elephant', 'human', 'rabbit', 'panda', 'cat', 'pigeon', 'human',
#        'sheep', 'human', 'elephant', 'pigeon', 'chicken', 'mouse',
#        'pigeon', 'cat', 'deer', 'deer', 'panda', 'rabbit', 'eagle',
#        'deer', 'dog', 'wolf', 'panda', 'bear', 'deer', 'cat', 'tiger',
#        'human', 'eagle', 'cat', 'human', 'monkey', 'deer', 'duck', 'cow',
#        'cat', 'monkey', 'pigeon', 'tiger', 'tiger', 'human', 'eagle',
#        'sheep', 'dog', 'pigeon', 'sheep', 'sheep', 'pigeon', 'bear',
#        'lion', 'eagle', 'wolf', 'elephant', 'panda', 'duck', 'mouse',
#        'lion', 'cat', 'sheep', 'human', 'bear', 'human', 'human',
#        'rabbit', 'dog', 'duck', 'duck', 'cow', 'sheep', 'mouse', 'lion',
#        'chicken', 'mouse', 'monkey', 'rabbit', 'duck', 'dog', 'sheep',
#        'mouse', 'wolf', 'cat', 'pigeon', 'bear', 'tiger', 'cat', 'dog',
#        'dog', 'bear', 'chicken', 'lion', 'tiger', 'bear', 'pigeon',
#        'lion', 'panda', 'panda', 'monkey', 'lion', 'human', 'wolf', 'dog',
#        'monkey', 'duck', 'sheep', 'monkey', 'tiger', 'panda', 'monkey',
#        'dog', 'cow', 'cat', 'panda', 'lion', 'wolf', 'elephant', 'rabbit',
#        'sheep', 'eagle', 'lion', 'eagle', 'mouse', 'bear', 'chicken',
#        'tiger', 'monkey', 'mouse', 'panda', 'rabbit', 'chicken', 'sheep',
#        'human', 'duck', 'deer', 'chicken', 'panda', 'duck', 'cat', 'dog',
#        'human', 'eagle', 'cat', 'duck', 'elephant', 'chicken', 'dog',
#        'elephant', 'deer', 'pigeon', 'mouse', 'chicken', 'panda', 'panda',
#        'tiger', 'chicken', 'eagle', 'lion', 'rabbit', 'monkey', 'eagle',
#        'dog', 'tiger', 'wolf', 'duck', 'cow', 'dog', 'dog', 'cat',
#        'monkey', 'duck', 'cat', 'panda', 'mouse', 'mouse', 'chicken',
#        'bear', 'elephant', 'monkey', 'cow', 'dog', 'pigeon', 'wolf',
#        'bear', 'wolf', 'sheep', 'cat', 'deer', 'cat', 'lion', 'tiger',
#        'duck', 'cat', 'cat', 'cow', 'cow', 'rabbit', 'tiger', 'chicken',
#        'lion', 'sheep', 'cat', 'deer', 'rabbit', 'monkey', 'tiger',
#        'panda', 'mouse', 'natural', 'rabbit', 'wolf', 'deer', 'chicken',
#        'lion', 'duck', 'human', 'cow', 'eagle', 'pigeon', 'mouse',
#        'pigeon', 'cow', 'mouse', 'human', 'mouse', 'pigeon', 'chicken',
#        'duck', 'duck', 'lion', 'bear', 'dog', 'human', 'rabbit', 'deer',
#        'monkey', 'chicken', 'monkey', 'sheep', 'tiger', 'chicken', 'wolf',
#        'dog', 'pigeon', 'tiger', 'mouse', 'tiger', 'chicken', 'chicken',
#        'dog', 'wolf', 'dog', 'human', 'duck', 'dog', 'cat', 'cat',
#        'human', 'panda', 'duck', 'eagle', 'eagle', 'cat', 'sheep',
#        'pigeon', 'rabbit', 'cow', 'pigeon', 'duck', 'cow', 'dog', 'human',
#        'human', 'dog', 'dog', 'cat', 'panda', 'mouse', 'rabbit', 'deer',
#        'tiger', 'panda', 'deer', 'wolf', 'monkey', 'tiger', 'wolf',
#        'chicken', 'chicken', 'eagle', 'cow', 'lion', 'sheep', 'cat',
#        'deer', 'panda', 'human', 'eagle', 'dog', 'wolf', 'lion', 'bear',
#        'sheep', 'sheep', 'tiger', 'human', 'cow', 'wolf', 'pigeon', 'cat',
#        'elephant', 'cow', 'human', 'rabbit', 'elephant', 'sheep', 'panda',
#        'panda', 'human', 'cat', 'dog', 'cat', 'monkey', 'duck', 'sheep',
#        'cat', 'cow', 'panda', 'sheep', 'tiger', 'mouse', 'rabbit', 'deer',
#        'human', 'eagle', 'pigeon', 'duck', 'chicken', 'cow', 'pigeon',
#        'cat', 'cow', 'bear', 'duck', 'natural', 'cat', 'human',
#        'elephant', 'dog', 'lion', 'human', 'rabbit', 'deer', 'chicken',
#        'cow', 'cat', 'dog', 'pigeon', 'chicken', 'tiger', 'dog',
#        'elephant', 'dog', 'rabbit', 'panda', 'cat', 'cat', 'eagle',
#        'mouse', 'elephant', 'sheep', 'dog', 'mouse', 'cat', 'cat',
#        'panda', 'elephant', 'tiger', 'cat', 'cat', 'wolf', 'panda',
#        'panda', 'sheep'], dtype='<U8')

# %% [markdown]
# ### Model Evaluation

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.615385  0.400000  0.484848   20.000000
# cat            0.657895  0.781250  0.714286   32.000000
# chicken        0.391304  0.450000  0.418605   20.000000
# cow            0.590909  0.619048  0.604651   21.000000
# deer           0.562500  0.428571  0.486486   21.000000
# dog            0.413793  0.461538  0.436364   26.000000
# duck           0.619048  0.619048  0.619048   21.000000
# eagle          0.312500  0.250000  0.277778   20.000000
# elephant       0.785714  0.550000  0.647059   20.000000
# human          0.678571  0.950000  0.791667   20.000000
# lion           0.529412  0.450000  0.486486   20.000000
# monkey         0.588235  0.500000  0.540541   20.000000
# mouse          0.363636  0.400000  0.380952   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.615385  0.666667  0.640000   24.000000
# pigeon         0.380952  0.347826  0.363636   23.000000
# rabbit         0.722222  0.650000  0.684211   20.000000
# sheep          0.480000  0.600000  0.533333   20.000000
# tiger          0.680000  0.739130  0.708333   23.000000
# wolf           0.842105  0.800000  0.820513   20.000000
# accuracy       0.565534  0.565534  0.565534    0.565534
# macro avg      0.541478  0.533154  0.531940  412.000000
# weighted avg   0.568897  0.565534  0.561776  412.000000

# %%
metrics.cohen_kappa_score(y_test,y_pred_test)
# Out:
# 0.5408284613133596

# %% [markdown]
# # Pipeline Model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipe = Pipeline([
    ('grayscale',rgb2gray_transform()),
    ('hogtransform',hogtransformer(orientations=8,pixels_per_cell=(10,10),cells_per_block=(3,3))),
    ('scaler',StandardScaler()),
    ('sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',
                         early_stopping=True,eta0=0.1))
])

# %%
model_pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('grayscale', rgb2gray_transform()),
#                 ('hogtransform',
#                  hogtransformer(orientations=8, pixels_per_cell=(10, 10))),
#                 ('scaler', StandardScaler()),
#                 ('sgd',
#                  SGDClassifier(early_stopping=True, eta0=0.1,
#                                learning_rate='adaptive'))])

# %%
y_pred = model_pipe.predict(x_test)

# %%
y_pred
# Out:
# array(['dog', 'cat', 'pigeon', 'panda', 'chicken', 'mouse', 'cow', 'wolf',
#        'panda', 'wolf', 'monkey', 'deer', 'chicken', 'rabbit', 'chicken',
#        'monkey', 'rabbit', 'deer', 'cat', 'duck', 'dog', 'elephant',
#        'sheep', 'elephant', 'elephant', 'wolf', 'wolf', 'tiger', 'dog',
#        'panda', 'human', 'rabbit', 'panda', 'cat', 'pigeon', 'human',
#        'pigeon', 'chicken', 'deer', 'pigeon', 'chicken', 'chicken',
#        'eagle', 'cat', 'chicken', 'deer', 'duck', 'deer', 'lion',
#        'pigeon', 'dog', 'wolf', 'panda', 'rabbit', 'deer', 'mouse',
#        'tiger', 'lion', 'pigeon', 'cat', 'human', 'monkey', 'deer',
#        'duck', 'rabbit', 'cat', 'bear', 'rabbit', 'tiger', 'tiger',
#        'natural', 'eagle', 'sheep', 'dog', 'pigeon', 'cow', 'mouse',
#        'pigeon', 'eagle', 'chicken', 'eagle', 'wolf', 'elephant', 'panda',
#        'duck', 'mouse', 'tiger', 'cat', 'sheep', 'cat', 'bear', 'human',
#        'human', 'rabbit', 'dog', 'bear', 'duck', 'cow', 'monkey',
#        'pigeon', 'chicken', 'cat', 'pigeon', 'duck', 'rabbit', 'duck',
#        'tiger', 'cow', 'mouse', 'deer', 'cat', 'pigeon', 'eagle', 'tiger',
#        'cat', 'lion', 'chicken', 'bear', 'chicken', 'lion', 'bear', 'dog',
#        'cow', 'panda', 'wolf', 'lion', 'eagle', 'lion', 'human', 'wolf',
#        'cat', 'monkey', 'lion', 'pigeon', 'monkey', 'tiger', 'panda',
#        'lion', 'dog', 'cow', 'cat', 'panda', 'eagle', 'dog', 'elephant',
#        'rabbit', 'cow', 'duck', 'lion', 'bear', 'bear', 'bear', 'monkey',
#        'tiger', 'monkey', 'mouse', 'panda', 'rabbit', 'rabbit', 'sheep',
#        'human', 'rabbit', 'pigeon', 'wolf', 'dog', 'duck', 'cat', 'dog',
#        'deer', 'pigeon', 'natural', 'duck', 'mouse', 'tiger', 'pigeon',
#        'eagle', 'wolf', 'pigeon', 'mouse', 'eagle', 'cow', 'mouse',
#        'elephant', 'panda', 'eagle', 'lion', 'rabbit', 'eagle', 'eagle',
#        'dog', 'dog', 'dog', 'lion', 'panda', 'duck', 'dog', 'wolf',
#        'monkey', 'duck', 'sheep', 'panda', 'cow', 'deer', 'wolf',
#        'rabbit', 'elephant', 'monkey', 'sheep', 'elephant', 'cat',
#        'eagle', 'bear', 'duck', 'eagle', 'cat', 'deer', 'pigeon',
#        'chicken', 'tiger', 'cat', 'cat', 'tiger', 'elephant', 'cow',
#        'rabbit', 'sheep', 'monkey', 'dog', 'sheep', 'cat', 'mouse',
#        'rabbit', 'dog', 'mouse', 'dog', 'lion', 'chicken', 'rabbit',
#        'bear', 'deer', 'eagle', 'lion', 'duck', 'human', 'cow', 'pigeon',
#        'pigeon', 'pigeon', 'pigeon', 'rabbit', 'bear', 'dog', 'mouse',
#        'pigeon', 'chicken', 'duck', 'duck', 'lion', 'pigeon', 'eagle',
#        'human', 'eagle', 'lion', 'monkey', 'natural', 'tiger', 'wolf',
#        'tiger', 'duck', 'dog', 'dog', 'pigeon', 'tiger', 'mouse', 'sheep',
#        'monkey', 'chicken', 'lion', 'lion', 'dog', 'human', 'duck',
#        'panda', 'cat', 'mouse', 'duck', 'panda', 'dog', 'panda', 'bear',
#        'cat', 'sheep', 'cow', 'cat', 'cow', 'pigeon', 'pigeon', 'pigeon',
#        'dog', 'dog', 'human', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog',
#        'deer', 'tiger', 'cat', 'deer', 'wolf', 'monkey', 'tiger', 'mouse',
#        'natural', 'sheep', 'bear', 'deer', 'lion', 'deer', 'sheep',
#        'wolf', 'panda', 'human', 'eagle', 'monkey', 'eagle', 'lion',
#        'mouse', 'panda', 'cow', 'sheep', 'human', 'elephant', 'wolf',
#        'bear', 'cat', 'elephant', 'cow', 'human', 'human', 'elephant',
#        'sheep', 'panda', 'rabbit', 'human', 'tiger', 'cat', 'cat',
#        'elephant', 'duck', 'monkey', 'monkey', 'human', 'panda', 'bear',
#        'tiger', 'mouse', 'rabbit', 'deer', 'human', 'sheep', 'sheep',
#        'duck', 'chicken', 'sheep', 'human', 'cat', 'cow', 'pigeon', 'dog',
#        'lion', 'duck', 'pigeon', 'sheep', 'dog', 'rabbit', 'human',
#        'rabbit', 'deer', 'monkey', 'cow', 'cow', 'lion', 'deer',
#        'chicken', 'cow', 'pigeon', 'elephant', 'dog', 'cow', 'panda',
#        'tiger', 'cat', 'eagle', 'tiger', 'cat', 'cat', 'tiger', 'pigeon',
#        'eagle', 'cat', 'panda', 'elephant', 'elephant', 'cat', 'eagle',
#        'wolf', 'tiger', 'lion', 'sheep'], dtype='<U8')

# %%
cr = pd.DataFrame(sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)).T

# %% [markdown]
# ## Grid Search
# - Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer()),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier())
])

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal'] 
    },
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate' : ['adaptive'],    
        'sgd__eta0' : [0.001,0.01]
    }
]

# %%
model_grid = GridSearchCV(estimator,
                          param_grid=param_grid,scoring='accuracy',
                          n_jobs=1,cv=3,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  11.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  10.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  10.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  10.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   4.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  12.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  11.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  11.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  11.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  11.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  10.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  10.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  10.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  11.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  11.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  12.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  12.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  11.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   6.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=  11.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  10.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  11.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=  11.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   8.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   9.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=  10.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   6.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   5.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   5.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   6.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   5.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  12.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  11.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.2s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  12.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  14.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  14.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  12.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  11.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  11.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.9s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.5s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.6s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  11.7s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.4s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  11.8s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  12.3s
# ...
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  16.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  20.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  18.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  20.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  15.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  14.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  15.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  16.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  16.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  14.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   7.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   7.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   7.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.3s
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 162 fits failed out of a total of 486.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 162 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\esinb\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\esinb\anaconda3\lib\site-packages\sklearn\pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\esinb\anaconda3\lib\site-packages\sklearn\pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "C:\Users\esinb\anaconda3\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\esinb\anaconda3\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\esinb\anaconda3\lib\site-packages\sklearn\base.py", line 855, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\esinb\AppData\Local\Temp\ipykernel_9620\3673342709.py", line 20, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\esinb\AppData\Local\Temp\ipykernel_9620\3673342709.py", line 20, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\esinb\AppData\Local\Temp\ipykernel_9620\3673342709.py", line 14, in local_hog
#     hog_features= skimage.feature.hog(img,orientations=self.orientations,
#   File "C:\Users\esinb\anaconda3\lib\site-packages\skimage\_shared\utils.py", line 394, in fixed_func
#     return func(*args, **kwargs)
#   File "C:\Users\esinb\anaconda3\lib\site-packages\skimage\_shared\utils.py", line 348, in fixed_func
#     return func(*args, **kwargs)
#   File "C:\Users\esinb\anaconda3\lib\site-packages\skimage\feature\_hog.py", line 233, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations),
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.70395521 0.70576563 0.71184503
#  0.71672118 0.71976254 0.72401602 0.71124673 0.70942523 0.71915648
#  0.70395078 0.70578557 0.70395189 0.71611512 0.71429584 0.73132083
#  0.69787913 0.70638055 0.70760706        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.69544494 0.69179419 0.69908903 0.74102992 0.72706292 0.73009653
#  0.71185611 0.71550796 0.71732945 0.69179309 0.69544715 0.69908903
#  0.72766233 0.71308705 0.7173217  0.70091385 0.70942302 0.69969287
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.5671781  0.46261617 0.52583219 0.51854289 0.51792354 0.52582998
#  0.56899406 0.46261506 0.5191423  0.53858819 0.52097488 0.52340132
#  0.56777308 0.20120857 0.51549932 0.52279415 0.5082211  0.51975833
#  0.53738161 0.49665173 0.5233991  0.52035331 0.51246571 0.50821334
#  0.57689495 0.49847766 0.5112259  0.52157872 0.49726444 0.51305625
#  0.5750657  0.36170166 0.51367228 0.50881053 0.49543629 0.51366342
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.5580518  0.53616728 0.53615842 0.53676337 0.53434358 0.53191603
#  0.56049819 0.53190827 0.51853625 0.55380386 0.52826196 0.51976055
#  0.56717146 0.51002929 0.50454376 0.53615177 0.50151016 0.53313257
#  0.54467424 0.54164617 0.54650349 0.54832609 0.5379921  0.541039
#  0.55440438 0.52764482 0.52096934 0.53191935 0.53191492 0.5276559
#  0.56899184 0.46808508 0.49724782 0.52825753 0.51791357 0.51366674]
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('grascale', rgb2gray_transform()),
#                                        ('hogtransform', hogtransformer()),
#                                        ('scale', StandardScaler()),
#                                        ('sgd', SGDClassifier())]),
#              n_jobs=1,
#              param_grid=[{'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__learning_rate': ['optimal'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']},
#                          {'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__eta0': [0.001, 0.01],
#                           'sgd__learning_rate': ['adaptive'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']}],
#              scoring='accuracy', verbose=2)

# %%
model_grid.best_params_
# Out:
# {'hogtransform__cells_per_block': (3, 3),
#  'hogtransform__orientations': 9,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7410299194731408

# %%
model_best = model_grid.best_estimator_

# %%
y_pred = model_best.predict(x_test)

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.812500  0.650000  0.722222   20.000000
# cat            0.933333  0.875000  0.903226   32.000000
# chicken        0.615385  0.800000  0.695652   20.000000
# cow            0.700000  0.666667  0.682927   21.000000
# deer           0.789474  0.714286  0.750000   21.000000
# dog            0.486486  0.692308  0.571429   26.000000
# duck           0.650000  0.619048  0.634146   21.000000
# eagle          0.523810  0.550000  0.536585   20.000000
# elephant       0.681818  0.750000  0.714286   20.000000
# human          0.947368  0.900000  0.923077   20.000000
# lion           0.714286  0.750000  0.731707   20.000000
# monkey         0.583333  0.700000  0.636364   20.000000
# mouse          0.611111  0.550000  0.578947   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.909091  0.833333  0.869565   24.000000
# pigeon         0.666667  0.608696  0.636364   23.000000
# rabbit         0.812500  0.650000  0.722222   20.000000
# sheep          0.625000  0.750000  0.681818   20.000000
# tiger          1.000000  0.695652  0.820513   23.000000
# wolf           0.850000  0.850000  0.850000   20.000000
# accuracy       0.718447  0.718447  0.718447    0.718447
# macro avg      0.695608  0.680249  0.683053  412.000000
# weighted avg   0.735772  0.718447  0.721855  412.000000

# %%
# save the model
pickle.dump(model_best,open('dsa_model_best.pickle','wb'))

# %% [markdown]
# ## Make Pipeline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDClassifier

# %%
pipeline1 = make_pipeline(rgb2gray_transform(),
                            hogtransformer(orientations=10,
                                           pixels_per_cell=(8,8),
                                           cells_per_block=(2,2)))

# %%
feature_vector = pipeline1.fit_transform(x_train)

# %%
# standard scaler
scalar = StandardScaler()
transformed_xtrain = scalar.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='hinge',alpha=0.01,early_stopping=True)

# %%
model.fit(transformed_xtrain,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True)

# %%
# evaluate
feature_vector = pipeline1.fit_transform(x_test)
transformed_x = scalar.transform(feature_vector)
y_pred_test = model.predict(transformed_x)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\esinb\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.764706  0.650000  0.702703   20.000000
# cat            1.000000  0.750000  0.857143   32.000000
# chicken        0.653846  0.850000  0.739130   20.000000
# cow            0.736842  0.666667  0.700000   21.000000
# deer           0.692308  0.857143  0.765957   21.000000
# dog            0.560976  0.884615  0.686567   26.000000
# duck           0.764706  0.619048  0.684211   21.000000
# eagle          0.437500  0.350000  0.388889   20.000000
# elephant       0.764706  0.650000  0.702703   20.000000
# human          1.000000  0.900000  0.947368   20.000000
# lion           0.640000  0.800000  0.711111   20.000000
# monkey         0.545455  0.600000  0.571429   20.000000
# mouse          0.590909  0.650000  0.619048   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.833333  0.833333  0.833333   24.000000
# pigeon         0.620690  0.782609  0.692308   23.000000
# rabbit         0.733333  0.550000  0.628571   20.000000
# sheep          0.789474  0.750000  0.769231   20.000000
# tiger          1.000000  0.652174  0.789474   23.000000
# wolf           0.850000  0.850000  0.850000   20.000000
# accuracy       0.720874  0.720874  0.720874    0.720874
# macro avg      0.698939  0.682279  0.681959  412.000000
# weighted avg   0.741094  0.720874  0.721159  412.000000

# %%
# save models for flask app
pickle.dump(model,open('dsa_image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scalar,open('dsa_scaler.pickle','wb'))

# %% [markdown]
# ---
